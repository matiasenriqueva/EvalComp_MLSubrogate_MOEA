# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
path_data = '../data/datatest.csv'
data = pd.read_csv(path_data)
data.head()
# Out:
#         u_q    coolant  stator_winding       u_d  stator_tooth  motor_speed  \
# 0 -0.450682  18.805172       19.086670 -0.350055     18.293219     0.002866
# 1 -0.325737  18.818571       19.092390 -0.305803     18.294807     0.000257
# 2 -0.440864  18.828770       19.089380 -0.372503     18.294094     0.002355
# 3 -0.327026  18.835567       19.083031 -0.316199     18.292542     0.006105
# 4 -0.471150  18.857033       19.082525 -0.332272     18.291428     0.003133
#
#         i_d       i_q         pm  stator_yoke    ambient    torque  profile_id
# 0  0.004419  0.000328  24.554214    18.316547  19.850691  0.187101          17
# 1  0.000606 -0.000785  24.538078    18.314955  19.850672  0.245417          17
# 2  0.001290  0.000386  24.544693    18.326307  19.850657  0.176615          17
# 3  0.000026  0.002046  24.554018    18.330833  19.850647  0.238303          17
# 4 -0.064317  0.037184  24.565397    18.326662  19.850639  0.208197          17

# %%
output_vars = ['pm', 'stator_yoke', 'stator_tooth', 'stator_winding']

# %%
col_names = data.columns
col_names
# Out:
# Index(['u_q', 'coolant', 'stator_winding', 'u_d', 'stator_tooth',
#        'motor_speed', 'i_d', 'i_q', 'pm', 'stator_yoke', 'ambient', 'torque',
#        'profile_id'],
#       dtype='object')

# %%
data = StandardScaler().fit_transform(data)
data = pd.DataFrame(data, columns=col_names)

# %%
data
# Out:
#               u_q   coolant  stator_winding       u_d  stator_tooth  \
# 0       -1.238979 -0.799812       -1.648158  0.392820     -1.681117
# 1       -1.236150 -0.799197       -1.647959  0.393521     -1.681047
# 2       -1.238757 -0.798729       -1.648064  0.392464     -1.681078
# 3       -1.236180 -0.798417       -1.648285  0.393356     -1.681146
# 4       -1.239442 -0.797432       -1.648303  0.393101     -1.681195
# ...           ...       ...             ...       ...           ...
# 1330811 -1.277497 -0.252853       -0.734801  0.410918     -0.651102
# 1330812 -1.279909 -0.252853       -0.736038  0.410713     -0.653952
# 1330813 -1.277003 -0.252853       -0.736995  0.411126     -0.656745
# 1330814 -1.280131 -0.252852       -0.737626  0.410463     -0.658601
# 1330815 -1.276320 -0.252852       -0.739760  0.411164     -0.659797
#
#          motor_speed       i_d       i_q        pm  stator_yoke   ambient  \
# 0          -1.184128  1.058337 -0.405855 -1.786837    -1.494244 -2.443386
# 1          -1.184129  1.058278 -0.405867 -1.787686    -1.494323 -2.443396
# 2          -1.184128  1.058289 -0.405854 -1.787338    -1.493755 -2.443404
# 3          -1.184126  1.058270 -0.405836 -1.786847    -1.493529 -2.443409
# 4          -1.184127  1.057279 -0.405455 -1.786248    -1.493738 -2.443413
# ...              ...       ...       ...       ...          ...       ...
# 1330811    -1.184129  1.027466 -0.393952  0.191617    -0.476927 -0.298612
# 1330812    -1.184128  1.027461 -0.393952  0.191347    -0.476796 -0.308136
# 1330813    -1.184128  1.027480 -0.393939  0.191122    -0.477067 -0.304750
# 1330814    -1.184126  1.027453 -0.393972  0.190861    -0.476829 -0.292215
# 1330815    -1.184127  1.027456 -0.393964  0.190756    -0.476594 -0.278688
#
#            torque  profile_id
# 0       -0.400838   -0.949994
# 1       -0.400082   -0.949994
# 2       -0.400974   -0.949994
# 3       -0.400174   -0.949994
# 4       -0.400565   -0.949994
# ...           ...         ...
# 1330811 -0.403264    1.206083
# 1330812 -0.403264    1.206083
# 1330813 -0.403264    1.206083
# 1330814 -0.403264    1.206083
# 1330815 -0.403264    1.206083
#
# [1330816 rows x 13 columns]

# %%
X = data.drop(output_vars + ['profile_id'], axis=1)
y = data[output_vars]

# %%
x_data = X.iloc[0:int(len(X.values)*0.1), :]
y_data = y.iloc[0:int(len(y.values)*0.1), :]

X_train, X_test_partial, y_train, y_test_partial = train_test_split(x_data, y_data, test_size=0.2, random_state=1)
X_test, X_next_test, y_test, y_next_test = train_test_split(X_test_partial, y_test_partial, test_size=0.05, random_state=1)

# %%
X_train
# Out:
#              u_q   coolant       u_d  motor_speed       i_d       i_q  \
# 62605   0.169930 -0.797383 -1.442551    -0.108675 -0.512835  1.693077
# 38458   0.653043 -0.818239 -0.953412    -0.108679  0.388159  1.032787
# 67896   1.512982 -0.804337 -0.419891     0.484977  0.369695  0.093686
# 105425 -1.134781 -0.816768  0.421870    -1.130350  1.027442 -0.393956
# 62231   0.176525 -0.778564 -1.440286    -0.108672 -0.508488  1.694424
# ...          ...       ...       ...          ...       ...       ...
# 73349  -0.569791 -0.785160 -1.629350     0.882353 -1.899235  0.683348
# 109259 -1.133113 -0.814792  0.421600    -1.130367  1.027449 -0.393964
# 50057   0.972416 -0.809868  0.391664    -0.108676  1.027444 -0.393955
# 5192    0.745651 -0.814288 -1.131462     1.504504 -1.070058  0.174074
# 128037  0.658397 -0.784836 -0.944365    -0.108682  0.388191  1.032789
#
#          ambient    torque
# 62605  -1.640411  1.695065
# 38458  -0.583505  0.917502
# 67896  -1.369987  0.052484
# 105425 -1.089553 -0.400082
# 62231  -1.177266  1.698851
# ...          ...       ...
# 73349  -0.789628  0.846427
# 109259 -1.536277 -0.400194
# 50057  -0.612086 -0.404261
# 5192   -0.446704  0.225733
# 128037 -0.197012  0.917332
#
# [106464 rows x 8 columns]

# %%
from sklearn.linear_model import SGDRegressor
from skmultiflow.meta import RegressorChain

# %%
rc = RegressorChain(SGDRegressor(loss='squared_error', random_state=1))
rc.fit(X_train.values, y_train.values)
# Out:
# RegressorChain(base_estimator=SGDRegressor(random_state=1), order=None,
#                random_state=None)

# %%
rc.predict(X_test.values)
# Out:
# array([[-0.12539231, -0.61221417, -0.42267923, -0.38895344],
#        [-0.55411074, -0.73139721, -0.63162664, -0.55067599],
#        [-1.13003468, -1.25581325, -1.39090848, -1.4964291 ],
#        ...,
#        [-0.45659344, -0.76324796, -0.65647005, -0.65564897],
#        [-1.27970093, -0.06537846,  0.30453651,  0.89905809],
#        [-0.44754813, -0.75781674, -0.64942579, -0.64810651]])

# %%
y_test.values
# Out:
# array([[-0.21750305, -0.73025483, -0.57113348, -0.56197817],
#        [-0.6064528 , -0.74718673, -0.64683649, -0.58518443],
#        [-1.22309882, -1.2241211 , -1.33965367, -1.41943825],
#        ...,
#        [-0.61557443, -0.84202962, -0.78751321, -0.81680022],
#        [-1.12150956,  0.21737407,  0.63543224,  1.24676272],
#        [-0.71935316, -0.85623823, -0.80515136, -0.8235825 ]])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test.values, rc.predict(X_test.values))
mse
# Out:
# 0.14706983240471777

# %%
rc.partial_fit(X_test.values, y_test.values)
# Out:
# RegressorChain(base_estimator=SGDRegressor(random_state=1), order=None,
#                random_state=None)

# %%
mse = mean_squared_error(y_next_test.values, rc.predict(X_next_test.values))
mse
# Out:
# 0.14284246973211967

# %%
from jmetal.algorithm.multiobjective.nsgaii import NSGAII
from jmetal.operator import PolynomialMutation, SBXCrossover
from jmetal.operator import BitFlipMutation, SPXCrossover
from jmetal.util.solution import get_non_dominated_solutions
from jmetal.util.termination_criterion import StoppingByEvaluations

# %%
from modnsgaii import NSGAII

from jmetal.problem import ZDT1

problem = ZDT1()

max_evaluations = 500
algorithm = NSGAII(
        problem=problem,
        population_size=100,
        offspring_population_size=100,
        mutation=PolynomialMutation(probability=1.0 / problem.number_of_variables(), distribution_index=20),
        crossover=SBXCrossover(probability=1.0, distribution_index=20),
        termination_criterion=StoppingByEvaluations(max_evaluations=max_evaluations),
        sample_size_ml=10
)

algorithm.run()
# Out:
# objectives sample
# [0.3230004923043077, 4.655637792820073]
